# %% [markdown]
# <a href="https://colab.research.google.com/github/YutangSSS/Global-Tech-ETF-Backtesting-Trend-Analysis/blob/main/Global_Tech_ETF_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

tickers = ["QQQ", "VGT", "SOXX"]

data = yf.download(tickers, start="2010-01-01")

prices = data.xs("Close", axis=1, level="Price")

plt.figure(figsize=(12, 6))
prices.plot(title="Global Tech ETFs: QQQ / VGT / SOXX - Close Prices")
plt.ylabel("Price (USD)")
plt.show()
# Out:
# ...
# /tmp/ipython-input-2177561832.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start="2010-01-01")  # 更长时间范围，更适合科技趋势
# [*********************100%***********************]  3 of 3 completed
